# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_csv("C:/Users/MOUNIKA/Documents/titanic.csv")

# %%
file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
file.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
file.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
file.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
file.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
file.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
file.shape
# Out:
# (891, 12)

# %%
file2 = file.head(300)
print(file2)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 295          296         0       1
# 296          297         0       3
# 297          298         0       1
# 298          299         1       1
# 299          300         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=file.iloc[1:300]
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 295          296         0       1
# 296          297         0       3
# 297          298         0       1
# 298          299         1       1
# 299          300         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 295          296         0       1
# 296          297         0       3
# 297          298         0       1
# 298          299         1       1
# 299          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 295                                Lewy, Mr. Ervin G    male   NaN      0
# 296                               Hanna, Mr. Mansour    male  23.5      0
# 297                     Allison, Miss. Helen Loraine  female   2.0      1
# 298                            Saalfeld, Mr. Adolphe    male   NaN      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 295      0  PC 17612   27.7208      NaN        C
# 296      0      2693    7.2292      NaN        C
# 297      2    113781  151.5500  C22 C26        S
# 298      0     19988   30.5000     C106        S
# 299      1  PC 17558  247.5208  B58 B60        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   299.000000  299.000000  299.000000  241.000000  299.000000
# mean    151.000000    0.361204    2.371237   28.984772    0.612040
# std      86.458082    0.481155    0.814699   14.830886    1.262517
# min       2.000000    0.000000    1.000000    0.830000    0.000000
# 25%      76.500000    0.000000    2.000000   19.000000    0.000000
# 50%     151.000000    0.000000    3.000000   28.000000    0.000000
# 75%     225.500000    1.000000    3.000000   37.000000    1.000000
# max     300.000000    1.000000    3.000000   71.000000    8.000000
#
#             Parch        Fare
# count  299.000000  299.000000
# mean     0.387960   29.786509
# std      0.796377   46.883686
# min      0.000000    0.000000
# 25%      0.000000    7.925000
# 50%      0.000000   14.454200
# 75%      0.000000   30.070800
# max      5.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (299, 12)

# %%
df['new'] = df['PassengerId'] + df['Survived']
# Out:
# C:\Users\MOUNIKA\AppData\Local\Temp\ipykernel_16996\2393193219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new'] = df['PassengerId'] + df['Survived']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  new
# 1      0          PC 17599  71.2833   C85        C    3
# 2      0  STON/O2. 3101282   7.9250   NaN        S    4
# 3      0            113803  53.1000  C123        S    5
# 4      0            373450   8.0500   NaN        S    5
# ...

# %%
df['Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
#        ...
# 295     NaN
# 296    23.5
# 297     2.0
# 298     NaN
# 299    50.0
# Name: Age, Length: 299, dtype: float64

# %%
df[['Age']]
# Out:
#       Age
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# ..    ...
# 295   NaN
# 296  23.5
# 297   2.0
# 298   NaN
# 299  50.0
#
# [299 rows x 1 columns]

# %%
df[['Name','Sex']]
# Out:
#                                                   Name     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# ..                                                 ...     ...
# 295                                  Lewy, Mr. Ervin G    male
# 296                                 Hanna, Mr. Mansour    male
# 297                       Allison, Miss. Helen Loraine  female
# 298                              Saalfeld, Mr. Adolphe    male
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female
#
# [299 rows x 2 columns]

# %%
df[df['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 276          277         0       3
# 280          281         0       3
# 288          289         1       2
# 292          293         0       2
# 299          300         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(['SibSp'],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  new
# 1      0          PC 17599  71.2833   C85        C    3
# 2      0  STON/O2. 3101282   7.9250   NaN        S    4
# 3      0            113803  53.1000  C123        S    5
# 4      0            373450   8.0500   NaN        S    5
# ...

# %%
df=df.rename(columns={'Cabin':'cabins'})

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# cabins          object
# Embarked        object
# new              int64
# dtype: object

# %%
pd.DataFrame({'Name':['mouni','percy','cherry','fathima','deepu'],'Age':[np.nan,21,22,23,np.nan],'Section':['a',np.nan,'a',np.nan,'c']})
# Out:
#       Name   Age Section
# 0    mouni   NaN       a
# 1    percy  21.0     NaN
# 2   cherry  22.0       a
# 3  fathima  23.0     NaN
# 4    deepu   NaN       c

# %%
df2=pd.DataFrame({'Name':['mouni','percy','cherry','fathima','deepu'],'Age':[np.nan,21,22,23,np.nan],'Section':['a',np.nan,'a',np.nan,'c']})

# %%
print(df2)
# Out:
#       Name   Age Section
# 0    mouni   NaN       a
# 1    percy  21.0     NaN
# 2   cherry  22.0       a
# 3  fathima  23.0     NaN
# 4    deepu   NaN       c

# %%
df2['Age'].fillna(20,inplace=True)
print(df2)
# Out:
#       Name   Age Section
# 0    mouni  20.0       a
# 1    percy  21.0     NaN
# 2   cherry  22.0       a
# 3  fathima  23.0     NaN
# 4    deepu  20.0       c
# C:\Users\MOUNIKA\AppData\Local\Temp\ipykernel_16996\1183558303.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Age'].fillna(20,inplace=True)

# %%
df2.head()
# Out:
#       Name   Age Section
# 0    mouni  20.0       a
# 1    percy  21.0     NaN
# 2   cherry  22.0       a
# 3  fathima  23.0     NaN
# 4    deepu  20.0       c

# %%
df2.dropna(inplace=True)
df2.head()
# Out:
#      Name   Age Section
# 0   mouni  20.0       a
# 2  cherry  22.0       a
# 4   deepu  20.0       c

# %%
##import matplotlib.pyplot as plt
df2.plot(X="Name",Y="Age",kind="line")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 ##import matplotlib.pyplot as plt
# ----> 2 df2.plot(X="Name",Y="Age",kind="line")
#
# File c:\users\mounika\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\users\mounika\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
